# %%
#Ve ngoi nha
import turtle
house=turtle.Turtle()
house.color('#6489bd')
house.pensize(3)
wall_h=80
wall_w=200
door_h=50
door_w=40
roof_h=60
roof_w=180
roof_angle=40
ong_khoi_w=15
ong_khoi_h=40
d_khoi_ong=12
khoi_h=40
khoi_w=12
house.hideturtle()
#chuyen but
house.penup()
house.forward(wall_w/2)
house.left(90)
house.forward(wall_h/2)
house.right(90)
house.pendown()
#ve tuong
house.right(90)
house.forward(wall_h)
house.right(90)
house.forward(wall_w)
house.right(90)
house.forward(wall_h)
goc_nha=house.pos()
# print(goc_nha)
house.right(90)
house.forward(wall_w)
#chuyen but
house.penup()
house.right(90)
house.forward(wall_h)
house.right(90)
house.forward((wall_w-door_w)/2)
house.pendown()
#Ve cua
house.forward(door_w)
house.right(90)
house.forward(door_h)
house.right(90)
house.forward(door_w)
house.right(90)
house.forward(door_h)
#chuyen but
house.penup()
# house.home()
# house.right(180)
# house.forward(wall_w/2)
# house.right(90)
# house.forward(wall_h/2)
house.goto(goc_nha)
house.left(180)
house.pendown()
#Ve mai
house.right(90-roof_angle)
house.forward(((roof_w/2)**2+roof_h**2)**0.5)
noc_nha=house.pos()
# print(noc_nha)
house.right(roof_angle*2)
house.forward(((roof_w/2)**2+roof_h**2)**0.5)
house.goto(goc_nha)
#chuyen but
house.penup()
house.goto(noc_nha)
a=(((roof_w/2)**2+roof_h**2)**0.5)/2
b=(((ong_khoi_w/2)**2)*2)**0.5
# print(a,b)
house.forward(a-b)
house.pendown()
#Ve ong khoi
house.left(90+roof_angle)
house.forward(ong_khoi_h-ong_khoi_w)
house.right(90)
house.forward(ong_khoi_w)
house.right(90)
house.forward(ong_khoi_h)
#chuyen but
house.penup()
house.left(180)
house.forward(ong_khoi_h+d_khoi_ong)
house.pendown()
#ve khoi
house.forward(khoi_h)
house.penup()
house.left(90)
house.forward(khoi_w)
house.left(90)
house.forward(khoi_w)
house.pendown()
house.forward(khoi_h/2)


#Ve cay
cay=turtle.Turtle()
cay.hideturtle()
#Kich thuoc cay
tan_cay_w=80
tan_cay_h=30
than_cay_w1=20
than_cay_w2=40
than_cay_h=80
cay.color('#7c9048')
cay.speed(2)
#Ve cay 1
#Chuyen but
cay.penup()
cay.goto(250,120)
#Nhap do lon cay 1
sc=1.2
#Tan cay 1
tan_cay_home=cay.pos()
cay.forward(tan_cay_w*sc/2)
tan_cay_right=cay.pos()
cay.penup()
cay.goto(tan_cay_home)
cay.left(90)
cay.forward(tan_cay_h*sc)
tan_cay_top=cay.pos()

cay.pendown()
cay.fillcolor('#c6d4a1')
cay.begin_fill()

cay.goto(tan_cay_right)
cay.left(90)
cay.forward(tan_cay_w*sc)
cay.goto(tan_cay_top)
cay.end_fill()
cay.penup()
cay.goto(tan_cay_home)
#Tan cay 2
tan_cay_top=cay.pos()
cay.left(90)
cay.forward((tan_cay_h+10)*sc)
tan_cay_home=cay.pos()
cay.left(90)
cay.forward((tan_cay_w+40)*sc/2)
tan_cay_right=cay.pos()
cay.left(180)
cay.pendown()
cay.fillcolor('#7c9048')
cay.begin_fill()
cay.forward((tan_cay_w+40)*sc)
cay.goto(tan_cay_top)
cay.goto(tan_cay_right)
cay.end_fill()
cay.penup()
cay.goto(tan_cay_home)
#Tan cay 3
tan_cay_top=cay.pos()
cay.left(90)
cay.forward((tan_cay_h+20)*sc)
tan_cay_home=cay.pos()
cay.left(90)
cay.forward((tan_cay_w+80)*sc/2)
tan_cay_right=cay.pos()
cay.left(180)
cay.pendown()
cay.fillcolor('#525f30')
cay.begin_fill()
cay.forward((tan_cay_w+80)*sc)
cay.goto(tan_cay_top)
cay.goto(tan_cay_right)
cay.end_fill()
cay.penup()
cay.goto(tan_cay_home)
#Than cay
cay.forward(than_cay_w1*sc/2)
than_cay_right_1=cay.pos()
cay.left(180)
cay.forward(than_cay_w1*sc)
than_cay_left_1=cay.pos()
cay.goto(tan_cay_home)
cay.right(90)
cay.forward(than_cay_h*sc)
cay.right(90)
cay.forward(than_cay_w2*sc/2)
than_cay_left_2=cay.pos()
cay.pendown()
cay.fillcolor('#808080')
cay.begin_fill()
cay.left(180)
cay.forward(than_cay_w2*sc)
than_cay_right_2=cay.pos()
cay.goto(than_cay_left_2)
cay.goto(than_cay_right_1)
cay.goto(than_cay_left_1)
cay.goto(than_cay_right_2)
cay.end_fill()
#Ve cay 2
#Chuyen but
cay.penup()
cay.goto(-150,10)
#Nhap do lon cay 1
sc=0.6
#Tan cay 1
tan_cay_home=cay.pos()
cay.forward(tan_cay_w*sc/2)
tan_cay_right=cay.pos()
cay.penup()
cay.goto(tan_cay_home)
cay.left(90)
cay.forward(tan_cay_h*sc)
tan_cay_top=cay.pos()

cay.pendown()
cay.fillcolor('#c6d4a1')
cay.begin_fill()

cay.goto(tan_cay_right)
cay.left(90)
cay.forward(tan_cay_w*sc)
cay.goto(tan_cay_top)
cay.end_fill()
cay.penup()
cay.goto(tan_cay_home)
#Tan cay 2
tan_cay_top=cay.pos()
cay.left(90)
cay.forward((tan_cay_h+10)*sc)
tan_cay_home=cay.pos()
cay.left(90)
cay.forward((tan_cay_w+40)*sc/2)
tan_cay_right=cay.pos()
cay.left(180)
cay.pendown()
cay.fillcolor('#7c9048')
cay.begin_fill()
cay.forward((tan_cay_w+40)*sc)
cay.goto(tan_cay_top)
cay.goto(tan_cay_right)
cay.end_fill()
cay.penup()
cay.goto(tan_cay_home)
#Tan cay 3
tan_cay_top=cay.pos()
cay.left(90)
cay.forward((tan_cay_h+20)*sc)
tan_cay_home=cay.pos()
cay.left(90)
cay.forward((tan_cay_w+80)*sc/2)
tan_cay_right=cay.pos()
cay.left(180)
cay.pendown()
cay.fillcolor('#525f30')
cay.begin_fill()
cay.forward((tan_cay_w+80)*sc)
cay.goto(tan_cay_top)
cay.goto(tan_cay_right)
cay.end_fill()
cay.penup()
cay.goto(tan_cay_home)
#Than cay
cay.forward(than_cay_w1*sc/2)
than_cay_right_1=cay.pos()
cay.left(180)
cay.forward(than_cay_w1*sc)
than_cay_left_1=cay.pos()
cay.goto(tan_cay_home)
cay.right(90)
cay.forward(than_cay_h*sc)
cay.right(90)
cay.forward(than_cay_w2*sc/2)
than_cay_left_2=cay.pos()
cay.pendown()
cay.fillcolor('#808080')
cay.begin_fill()
cay.left(180)
cay.forward(than_cay_w2*sc)
than_cay_right_2=cay.pos()
cay.goto(than_cay_left_2)
cay.goto(than_cay_right_1)
cay.goto(than_cay_left_1)
cay.goto(than_cay_right_2)
cay.end_fill()
