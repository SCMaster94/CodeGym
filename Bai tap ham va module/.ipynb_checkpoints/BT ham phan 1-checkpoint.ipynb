# %%
#1
def tong_uoc_chan(num):
    tong_uoc_chan=0
    if num%2==0:
        for i in range (2,num+1,2):
            if num%i==0:
#                 print(i)
                tong_uoc_chan+=i
        else:
            return (tong_uoc_chan)
    else:
        print("So le thi lam gi co uoc chan")
while True:
    n=int(input('Nhap so nguyen duong n: '))
    if n>0:
        break
    else:
        print("Ban can nhap so nguyen duong")
total=tong_uoc_chan(n)
print(total)

# %%
#2
def uoc_le_max(num):
    uoc_le_max=0
    for i in range (1,num+1,2):
        if num%i==0:
#             print(i)
            uoc_le_max=i
    else:
        return (uoc_le_max)
while True:
    n=int(input('Nhap so nguyen duong n: '))
    if n>0:
        break
    else:
        print("Ban can nhap so nguyen duong")
odd_max=uoc_le_max(n)
print(odd_max)

# %%
#3
def so_lan_gap(paper_thick, thick):
    i=0
    while paper_thick<=thick:
        paper_thick=paper_thick*2
        i+=1
    return i
paper_thick=float(input("Nhap chieu day to giay can gap: "))
thick=float(input("Nhap chieu day can gap: "))
n=so_lan_gap(paper_thick, thick)
print(f"Can gap {n: .0f} lan de to giay day {paper_thick: .2f}mm co do day {thick: .2f}mm")

# %%
#4
def check(num):
    i=1
    print_str=''
    for B in range (1,num):
        for A in range (1,B):
            if (A*A+B*B+1)%(A*B)==0:
#                 print(A*A+B*B+1,A*B)
                print_str+=f"Cap so {i} la: {A} va {B}\n"
                i+=1
    if print_str=='':
        print_str='Khong co cap so nao'
        return (print_str)
    else:
        return (print_str)
while True:
    n=int(input("Nhap co nguyen duong can check: "))
    if n>0:
        break
str_check=check(n)
print(str_check)
# Out:
# Nhap co nguyen duong can check: 1000
# Cap so 1 la: 1 va 2
# Cap so 2 la: 2 va 5
# Cap so 3 la: 5 va 13
# Cap so 4 la: 13 va 34
# Cap so 5 la: 34 va 89
# Cap so 6 la: 89 va 233
# Cap so 7 la: 233 va 610

# %%
#5
def dem_tien(money_total):
    so_to_min=0
    so_pa=0
    if money_total%1000!=0:
        print("So tien khong kha dung")
    else:
        for to_5000 in range (money_total//5000+1):
            money_5000=money_total
            to_1000=0
            money_5000=money_5000-to_5000*5000
            for to_2000 in range (money_5000//2000+1):
                money_2000=money_5000
                money_2000=money_2000-to_2000*2000
                to_1000=money_2000/1000
                so_to=to_5000+to_2000+to_1000
                so_pa+=1
                print(f"Phuong an {so_pa}: {to_5000} to 5000, {to_2000} to 2000, {to_1000:.0f} to 1000")               
            if so_to_min==0 or so_to<so_to_min:
                so_to_min=so_to
                pa_min=so_pa
    print(f"Phuong an toi uu la phuong {pa_min} voi {so_to_min} to tien")
money = int(input("Nhap so tien la boi so cua 1000: "))
dem_tien(money)
# Out:
# Nhap so tien la boi so cua 1000: 33000
# Phuong an 1: 0 to 5000, 0 to 2000, 33 to 1000
# Phuong an 2: 0 to 5000, 1 to 2000, 31 to 1000
# Phuong an 3: 0 to 5000, 2 to 2000, 29 to 1000
# Phuong an 4: 0 to 5000, 3 to 2000, 27 to 1000
# Phuong an 5: 0 to 5000, 4 to 2000, 25 to 1000
# Phuong an 6: 0 to 5000, 5 to 2000, 23 to 1000
# Phuong an 7: 0 to 5000, 6 to 2000, 21 to 1000
# Phuong an 8: 0 to 5000, 7 to 2000, 19 to 1000
# Phuong an 9: 0 to 5000, 8 to 2000, 17 to 1000
# Phuong an 10: 0 to 5000, 9 to 2000, 15 to 1000
# Phuong an 11: 0 to 5000, 10 to 2000, 13 to 1000
# Phuong an 12: 0 to 5000, 11 to 2000, 11 to 1000
# Phuong an 13: 0 to 5000, 12 to 2000, 9 to 1000
# Phuong an 14: 0 to 5000, 13 to 2000, 7 to 1000
# Phuong an 15: 0 to 5000, 14 to 2000, 5 to 1000
# Phuong an 16: 0 to 5000, 15 to 2000, 3 to 1000
# Phuong an 17: 0 to 5000, 16 to 2000, 1 to 1000
# Phuong an 18: 1 to 5000, 0 to 2000, 28 to 1000
# Phuong an 19: 1 to 5000, 1 to 2000, 26 to 1000
# Phuong an 20: 1 to 5000, 2 to 2000, 24 to 1000
# Phuong an 21: 1 to 5000, 3 to 2000, 22 to 1000
# Phuong an 22: 1 to 5000, 4 to 2000, 20 to 1000
# Phuong an 23: 1 to 5000, 5 to 2000, 18 to 1000
# Phuong an 24: 1 to 5000, 6 to 2000, 16 to 1000
# Phuong an 25: 1 to 5000, 7 to 2000, 14 to 1000
# Phuong an 26: 1 to 5000, 8 to 2000, 12 to 1000
# Phuong an 27: 1 to 5000, 9 to 2000, 10 to 1000
# Phuong an 28: 1 to 5000, 10 to 2000, 8 to 1000
# Phuong an 29: 1 to 5000, 11 to 2000, 6 to 1000
# Phuong an 30: 1 to 5000, 12 to 2000, 4 to 1000
# Phuong an 31: 1 to 5000, 13 to 2000, 2 to 1000
# Phuong an 32: 1 to 5000, 14 to 2000, 0 to 1000
# Phuong an 33: 2 to 5000, 0 to 2000, 23 to 1000
# Phuong an 34: 2 to 5000, 1 to 2000, 21 to 1000
# Phuong an 35: 2 to 5000, 2 to 2000, 19 to 1000
# Phuong an 36: 2 to 5000, 3 to 2000, 17 to 1000
# Phuong an 37: 2 to 5000, 4 to 2000, 15 to 1000
# Phuong an 38: 2 to 5000, 5 to 2000, 13 to 1000
# Phuong an 39: 2 to 5000, 6 to 2000, 11 to 1000
# Phuong an 40: 2 to 5000, 7 to 2000, 9 to 1000
# Phuong an 41: 2 to 5000, 8 to 2000, 7 to 1000
# Phuong an 42: 2 to 5000, 9 to 2000, 5 to 1000
# Phuong an 43: 2 to 5000, 10 to 2000, 3 to 1000
# Phuong an 44: 2 to 5000, 11 to 2000, 1 to 1000
# Phuong an 45: 3 to 5000, 0 to 2000, 18 to 1000
# Phuong an 46: 3 to 5000, 1 to 2000, 16 to 1000
# Phuong an 47: 3 to 5000, 2 to 2000, 14 to 1000
# Phuong an 48: 3 to 5000, 3 to 2000, 12 to 1000
# Phuong an 49: 3 to 5000, 4 to 2000, 10 to 1000
# Phuong an 50: 3 to 5000, 5 to 2000, 8 to 1000
# Phuong an 51: 3 to 5000, 6 to 2000, 6 to 1000
# Phuong an 52: 3 to 5000, 7 to 2000, 4 to 1000
# Phuong an 53: 3 to 5000, 8 to 2000, 2 to 1000
# Phuong an 54: 3 to 5000, 9 to 2000, 0 to 1000
# Phuong an 55: 4 to 5000, 0 to 2000, 13 to 1000
# Phuong an 56: 4 to 5000, 1 to 2000, 11 to 1000
# Phuong an 57: 4 to 5000, 2 to 2000, 9 to 1000
# Phuong an 58: 4 to 5000, 3 to 2000, 7 to 1000
# Phuong an 59: 4 to 5000, 4 to 2000, 5 to 1000
# Phuong an 60: 4 to 5000, 5 to 2000, 3 to 1000
# Phuong an 61: 4 to 5000, 6 to 2000, 1 to 1000
# Phuong an 62: 5 to 5000, 0 to 2000, 8 to 1000
# Phuong an 63: 5 to 5000, 1 to 2000, 6 to 1000
# Phuong an 64: 5 to 5000, 2 to 2000, 4 to 1000
# Phuong an 65: 5 to 5000, 3 to 2000, 2 to 1000
# Phuong an 66: 5 to 5000, 4 to 2000, 0 to 1000
# Phuong an 67: 6 to 5000, 0 to 2000, 3 to 1000
# Phuong an 68: 6 to 5000, 1 to 2000, 1 to 1000
# Phuong an toi uu la phuong 68 voi 8.0 to tien
