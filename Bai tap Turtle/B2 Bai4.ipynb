# %%
import turtle
import math
h=turtle.Turtle()
canh=100
n=3
goc_giua=360/n
goc_ngoai=(180-goc_giua)/2
goc_ngoai_radian=math.radians(goc_ngoai)
canh_ngoai=2*math.cos(goc_ngoai_radian)*canh


h.fd(canh)
h.lt(180-goc_ngoai)
h.fd(canh_ngoai)
h.lt(180-goc_ngoai)
h.fd(canh)

h.lt(180)
h.fd(canh)
h.lt(180-goc_ngoai)
h.fd(canh_ngoai)
h.lt(180-goc_ngoai)
h.fd(canh)

h.lt(180)
h.fd(canh)
h.lt(180-goc_ngoai)
h.fd(canh_ngoai)
h.lt(180-goc_ngoai)
h.fd(canh)


h.lt(180)
h.fd(canh)
h.lt(180-goc_ngoai)
h.fd(canh_ngoai)
h.lt(180-goc_ngoai)
h.fd(canh)


h.lt(180)
h.fd(canh)
h.lt(180-goc_ngoai)
h.fd(canh_ngoai)
h.lt(180-goc_ngoai)
h.fd(canh)


h.lt(180)
h.fd(canh)
h.lt(180-goc_ngoai)
h.fd(canh_ngoai)
h.lt(180-goc_ngoai)
h.fd(canh)


h.lt(180)
h.fd(canh)
h.lt(180-goc_ngoai)
h.fd(canh_ngoai)
h.lt(180-goc_ngoai)
h.fd(canh)

h.lt(180)
h.fd(canh)
h.lt(180-goc_ngoai)
h.fd(canh_ngoai)
h.lt(180-goc_ngoai)
h.fd(canh)

h.lt(180)
h.fd(canh)
h.lt(180-goc_ngoai)
h.fd(canh_ngoai)
h.lt(180-goc_ngoai)
h.fd(canh)

h.lt(180)
h.fd(canh)
h.lt(180-goc_ngoai)
h.fd(canh_ngoai)
h.lt(180-goc_ngoai)
h.fd(canh)


h.lt(180)
h.fd(canh)
h.lt(180-goc_ngoai)
h.fd(canh_ngoai)
h.lt(180-goc_ngoai)
h.fd(canh)



turtle.done()
